# %% [markdown]
# # CHIMERA-QRC — judge verification (Team EIGENNEXUS, GIC 2026 Track A)
#
# Run the two cells below (or *Run → Run All Cells*). Everything is **offline** — no API key,
# credits, or accounts. Cell 2 is the one-command integrity audit: 24 engine tests, the
# QASM=reservoir self-test, the whole-program credit reconciliation, shot-noise bootstrap CIs,
# and the coherent-vs-damping noise fingerprint (~2–5 min depending on cores).

# %%
# %pip install -q -r requirements.txt

# %%
# !python3 cli.py verify

# %% [markdown]
# **Going deeper:** `!python3 cli.py headline --quick` (~10 min) replays the Phase-3 story —
# pre-registration → decisive HAR-X test → canonical baselines → MNIST → frontier.
# `!python3 reproduce.py` is the full reproduction (~1–2 h). `!python3 cli.py list` shows every
# action. A browser replay of the audit lives at `docs/verify_replay.html`; the findings, job
# IDs and raw counts are under `results/`.
